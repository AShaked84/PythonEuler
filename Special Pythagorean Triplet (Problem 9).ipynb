# %%
def triplets(mysum):
    m = 2; n = 1

    while m < 100:
        while n < m:
            a = m*m - n*n
            b = 2*n*m
            c = n*n + m*m

            if sum([a, b, c]) == mysum:
                return a*b*c
            else: 
                n += 1
        m += 1

# %%
print(sum([8, 6, 10]))
# Out:
# 24

# %%
print(triplets(24))
# Out:
# None
